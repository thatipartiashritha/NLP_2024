# %% [markdown]
# <a href="https://colab.research.google.com/github/thatipartiashritha/NLP_2024/blob/main/NLP_ASS_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow numpy
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Example data (small English to French pairs)
data = [("hello", "bonjour"),
        ("how are you", "comment ça va"),
        ("I am fine", "je vais bien"),
        ("what is your name", "comment tu t'appelles"),
        ("my name is", "je m'appelle"),
        ("thank you", "merci"),
        ("goodbye", "au revoir")]

# Splitting the data into input (English) and output (French) pairs
english_sentences, french_sentences = zip(*data)

# Tokenize English sentences
eng_tokenizer = Tokenizer()
eng_tokenizer.fit_on_texts(english_sentences)
eng_sequences = eng_tokenizer.texts_to_sequences(english_sentences)
eng_word_index = eng_tokenizer.word_index
max_eng_len = max(len(seq) for seq in eng_sequences)

# Tokenize French sentences
fr_tokenizer = Tokenizer()
fr_tokenizer.fit_on_texts(french_sentences)
fr_sequences = fr_tokenizer.texts_to_sequences(french_sentences)
fr_word_index = fr_tokenizer.word_index
max_fr_len = max(len(seq) for seq in fr_sequences)

# Padding sequences
eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
fr_padded = pad_sequences(fr_sequences, maxlen=max_fr_len, padding='post')

# Vocabulary sizes
eng_vocab_size = len(eng_word_index) + 1
fr_vocab_size = len(fr_word_index) + 1

# %% [markdown]
# Build Seq2Seq Model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding

# Encoder
latent_dim = 256

encoder_inputs = Input(shape=(max_eng_len,))
enc_emb = Embedding(eng_vocab_size, latent_dim)(encoder_inputs)

encoder_lstm = LSTM(latent_dim, return_state=True)
_, state_h, state_c = encoder_lstm(enc_emb)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(max_fr_len,))
dec_emb_layer = Embedding(fr_vocab_size, latent_dim)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=encoder_states)

decoder_dense = Dense(fr_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Seq2Seq model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 4)              │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_1             │ (None, 3)              │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding (Embedding)     │ (None, 4, 256)         │          3,840 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ embedding_1 (Embedding)   │ (None, 3, 256)         │          3,584 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm (LSTM)               │ [(None, 256), (None,   │        525,312 │ embedding[0][0]        │
# │                           │ 256), (None, 256)]     │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_1 (LSTM)             │ [(None, 3, 256),       │        525,312 │ embedding_1[0][0],     │
# │                           │ (None, 256), (None,    │                │ lstm[0][1], lstm[0][2] │
# │                           │ 256)]                  │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 3, 14)          │          3,598 │ lstm_1[0][0]           │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 1,061,646 (4.05 MB)
#  Trainable params: 1,061,646 (4.05 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
#  Preparing the Data for Training

# %%
# Preparing decoder target data (shifted French sentences)
fr_padded_target = np.zeros_like(fr_padded)
fr_padded_target[:, :-1] = fr_padded[:, 1:]

# Train/Val Split
train_size = int(0.8 * len(eng_padded))
eng_train, eng_val = eng_padded[:train_size], eng_padded[train_size:]
fr_train, fr_val = fr_padded[:train_size], fr_padded[train_size:]
fr_target_train, fr_target_val = fr_padded_target[:train_size], fr_padded_target[train_size:]

# %% [markdown]
# Train the Model on the Dataset

# %%
batch_size = 64
epochs = 100

history = model.fit([eng_train, fr_train], fr_target_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    validation_data=([eng_val, fr_val], fr_target_val))
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - accuracy: 0.0000e+00 - loss: 2.6386 - val_accuracy: 0.8333 - val_loss: 2.5812
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step - accuracy: 0.6000 - loss: 2.5915 - val_accuracy: 0.8333 - val_loss: 2.5147
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.5333 - loss: 2.5416 - val_accuracy: 0.8333 - val_loss: 2.4362
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5333 - loss: 2.4841 - val_accuracy: 0.8333 - val_loss: 2.3376
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5333 - loss: 2.4138 - val_accuracy: 0.8333 - val_loss: 2.2094
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5333 - loss: 2.3246 - val_accuracy: 0.8333 - val_loss: 2.0405
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5333 - loss: 2.2096 - val_accuracy: 0.8333 - val_loss: 1.8197
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5333 - loss: 2.0621 - val_accuracy: 0.8333 - val_loss: 1.5421
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5333 - loss: 1.8805 - val_accuracy: 0.8333 - val_loss: 1.2307
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5333 - loss: 1.6796 - val_accuracy: 0.8333 - val_loss: 0.9703
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5333 - loss: 1.4989 - val_accuracy: 0.8333 - val_loss: 0.8642
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5333 - loss: 1.3974 - val_accuracy: 0.8333 - val_loss: 0.9155
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5333 - loss: 1.4185 - val_accuracy: 0.8333 - val_loss: 1.0152
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5333 - loss: 1.4733 - val_accuracy: 0.8333 - val_loss: 1.0752
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5333 - loss: 1.4607 - val_accuracy: 0.8333 - val_loss: 1.0876
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5333 - loss: 1.3868 - val_accuracy: 0.8333 - val_loss: 1.0703
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5333 - loss: 1.2926 - val_accuracy: 0.8333 - val_loss: 1.0428
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5333 - loss: 1.2119 - val_accuracy: 0.8333 - val_loss: 1.0193
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5333 - loss: 1.1594 - val_accuracy: 0.8333 - val_loss: 1.0068
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5333 - loss: 1.1320 - val_accuracy: 0.8333 - val_loss: 1.0057
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5333 - loss: 1.1170 - val_accuracy: 0.8333 - val_loss: 1.0128
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5333 - loss: 1.1014 - val_accuracy: 0.8333 - val_loss: 1.0250
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5333 - loss: 1.0772 - val_accuracy: 0.8333 - val_loss: 1.0406
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6000 - loss: 1.0412 - val_accuracy: 0.8333 - val_loss: 1.0596
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6000 - loss: 0.9940 - val_accuracy: 0.8333 - val_loss: 1.0838
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.6000 - loss: 0.9390 - val_accuracy: 0.8333 - val_loss: 1.1148
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.6000 - loss: 0.8806 - val_accuracy: 0.8333 - val_loss: 1.1541
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6000 - loss: 0.8229 - val_accuracy: 0.8333 - val_loss: 1.2016
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6000 - loss: 0.7687 - val_accuracy: 0.8333 - val_loss: 1.2557
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6000 - loss: 0.7177 - val_accuracy: 0.8333 - val_loss: 1.3137
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6000 - loss: 0.6679 - val_accuracy: 0.8333 - val_loss: 1.3721
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7333 - loss: 0.6164 - val_accuracy: 0.8333 - val_loss: 1.4283
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8000 - loss: 0.5615 - val_accuracy: 0.8333 - val_loss: 1.4810
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8000 - loss: 0.5040 - val_accuracy: 0.8333 - val_loss: 1.5306
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9333 - loss: 0.4473 - val_accuracy: 0.8333 - val_loss: 1.5792
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.3959 - val_accuracy: 0.8333 - val_loss: 1.6299
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - loss: 0.3532 - val_accuracy: 0.8333 - val_loss: 1.6866
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.3179 - val_accuracy: 0.8333 - val_loss: 1.7523
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.2843 - val_accuracy: 0.8333 - val_loss: 1.8292
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.2495 - val_accuracy: 0.8333 - val_loss: 1.9171
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.2160 - val_accuracy: 0.8333 - val_loss: 2.0142
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.1866 - val_accuracy: 0.8333 - val_loss: 2.1162
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.1633 - val_accuracy: 0.8333 - val_loss: 2.2182
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.1456 - val_accuracy: 0.8333 - val_loss: 2.3152
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.1307 - val_accuracy: 0.8333 - val_loss: 2.4041
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.1164 - val_accuracy: 0.8333 - val_loss: 2.4835
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.1020 - val_accuracy: 0.8333 - val_loss: 2.5536
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0880 - val_accuracy: 0.8333 - val_loss: 2.6162
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0754 - val_accuracy: 0.8333 - val_loss: 2.6734
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 1.0000 - loss: 0.0651 - val_accuracy: 0.8333 - val_loss: 2.7272
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0570 - val_accuracy: 0.8333 - val_loss: 2.7795
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0507 - val_accuracy: 0.8333 - val_loss: 2.8318
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.0454 - val_accuracy: 0.8333 - val_loss: 2.8850
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0399 - val_accuracy: 0.8333 - val_loss: 2.9385
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0344 - val_accuracy: 0.8333 - val_loss: 2.9903
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 1.0000 - loss: 0.0298 - val_accuracy: 0.8333 - val_loss: 3.0383
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0262 - val_accuracy: 0.8333 - val_loss: 3.0811
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0234 - val_accuracy: 0.8333 - val_loss: 3.1179
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.0211 - val_accuracy: 0.8333 - val_loss: 3.1486
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0189 - val_accuracy: 0.8333 - val_loss: 3.1737
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 0.8333 - val_loss: 3.1937
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.8333 - val_loss: 3.2097
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 1.0000 - loss: 0.0134 - val_accuracy: 0.8333 - val_loss: 3.2228
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 0.8333 - val_loss: 3.2339
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.8333 - val_loss: 3.2440
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.8333 - val_loss: 3.2539
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.8333 - val_loss: 3.2643
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.8333 - val_loss: 3.2755
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.8333 - val_loss: 3.2876
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.8333 - val_loss: 3.3002
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.8333 - val_loss: 3.3131
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.8333 - val_loss: 3.3255
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.8333 - val_loss: 3.3371
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.8333 - val_loss: 3.3475
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.8333 - val_loss: 3.3565
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.8333 - val_loss: 3.3640
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.8333 - val_loss: 3.3700
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.8333 - val_loss: 3.3746
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.8333 - val_loss: 3.3781
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8333 - val_loss: 3.3806
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.8333 - val_loss: 3.3825
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8333 - val_loss: 3.3841
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.8333 - val_loss: 3.3855
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.8333 - val_loss: 3.3870
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8333 - val_loss: 3.3888
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8333 - val_loss: 3.3908
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.8333 - val_loss: 3.3932
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8333 - val_loss: 3.3960
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.8333 - val_loss: 3.3990
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.8333 - val_loss: 3.4021
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8333 - val_loss: 3.4053
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8333 - val_loss: 3.4084
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.8333 - val_loss: 3.4113
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8333 - val_loss: 3.4139
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8333 - val_loss: 3.4162
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8333 - val_loss: 3.4182
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8333 - val_loss: 3.4199
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8333 - val_loss: 3.4212
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.8333 - val_loss: 3.4224
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8333 - val_loss: 3.4233

# %% [markdown]
# Inference Setup for Translation

# %%
# Inference Encoder
encoder_model = Model(encoder_inputs, encoder_states)

# Inference Decoder
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

dec_emb2 = dec_emb_layer(decoder_inputs)

decoder_outputs2, state_h2, state_c2 = decoder_lstm(
    dec_emb2, initial_state=decoder_states_inputs)
decoder_states2 = [state_h2, state_c2]
decoder_outputs2 = decoder_dense(decoder_outputs2)

decoder_model = Model([decoder_inputs] + decoder_states_inputs,
                      [decoder_outputs2] + decoder_states2)

# %% [markdown]
#  Translate New Sentences

# %%
# Add 'start' and 'end' tokens to French sentences
french_sentences_with_tokens = ['start ' + sent + ' end' for sent in french_sentences]

# Tokenize French sentences with start and end tokens
fr_tokenizer = Tokenizer()
fr_tokenizer.fit_on_texts(french_sentences_with_tokens)
fr_sequences = fr_tokenizer.texts_to_sequences(french_sentences_with_tokens)
fr_word_index = fr_tokenizer.word_index
max_fr_len = max(len(seq) for seq in fr_sequences)

# Padding sequences
eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
fr_padded = pad_sequences(fr_sequences, maxlen=max_fr_len, padding='post')

# %%
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)

    # Start with the 'start' token
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = fr_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = None
        for word, index in fr_word_index.items():
            if index == sampled_token_index:
                sampled_word = word
                break

        if sampled_word == 'end' or len(decoded_sentence) > max_fr_len:
            stop_condition = True
        else:
            decoded_sentence += sampled_word + ' '

        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index
        states_value = [h, c]

    return decoded_sentence

# %%
def decode_sequence(input_seq):
    states_value = encoder_model.predict(input_seq)

    # Start with the 'start' token
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = fr_word_index['start']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Get the index of the most likely next word
        sampled_token_index = np.argmax(output_tokens[0, -1, :])

        # Retrieve the corresponding word for the token index
        sampled_word = None
        for word, index in fr_word_index.items():
            if index == sampled_token_index:
                sampled_word = word
                break

        # Handle the case where the word is not found
        if sampled_word is None:
            print(f"Warning: No word found for token index {sampled_token_index}")
            stop_condition = True
        elif sampled_word == 'end' or len(decoded_sentence.split()) > max_fr_len:
            stop_condition = True
        else:
            decoded_sentence += sampled_word + ' '

        # Update the target sequence to the predicted word
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states for the next iteration
        states_value = [h, c]

    return decoded_sentence

# %%
# Testing with a new sentence
test_sentence = "hello"
test_sequence = eng_tokenizer.texts_to_sequences([test_sentence])
test_sequence = pad_sequences(test_sequence, maxlen=max_eng_len, padding='post')

translation = decode_sequence(test_sequence)
print(f"Translation: {translation}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Warning: No word found for token index 0
# Translation:

# %% [markdown]
#  Experimenting and Improving the Model with a Larger Dataset

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.optimizers import Adam

# Define the latent_dim and other hyperparameters
latent_dim = 256
eng_vocab_size = 15  # Example value; replace with actual vocab size
fr_vocab_size = 15   # Example value; replace with actual vocab size
embedding_dim = 128  # Size of the embedding vectors

# Define encoder
encoder_inputs = Input(shape=(None,))  # Only the sequence length is needed here
encoder_embedding = Embedding(input_dim=eng_vocab_size, output_dim=embedding_dim)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_sequences=True)(encoder_embedding)
encoder_outputs, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_lstm)
encoder_states = [state_h, state_c]

# Define decoder
decoder_inputs = Input(shape=(None,))  # Only the sequence length is needed here
decoder_embedding = Embedding(input_dim=fr_vocab_size, output_dim=embedding_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True)(decoder_embedding, initial_state=encoder_states)
decoder_outputs = Dense(fr_vocab_size, activation='softmax')(decoder_lstm)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
opt = Adam(learning_rate=0.0005)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Check the shapes of the training data
# Ensure eng_train, fr_train, and fr_target_train have the appropriate shapes
print(f"eng_train shape: {eng_train.shape}, fr_train shape: {fr_train.shape}, fr_target_train shape: {fr_target_train.shape}")

# Train the model
model.fit([eng_train, fr_train], fr_target_train, batch_size=batch_size, epochs=200, validation_data=([eng_val, fr_val], fr_target_val))
# Out:
# eng_train shape: (5, 4), fr_train shape: (5, 3), fr_target_train shape: (5, 3)
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.0000e+00 - loss: 2.7099 - val_accuracy: 0.6667 - val_loss: 2.6939
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.4667 - loss: 2.6973 - val_accuracy: 0.8333 - val_loss: 2.6785
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5333 - loss: 2.6843 - val_accuracy: 0.8333 - val_loss: 2.6615
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 2.6702 - val_accuracy: 0.8333 - val_loss: 2.6423
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5333 - loss: 2.6545 - val_accuracy: 0.8333 - val_loss: 2.6198
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 2.6366 - val_accuracy: 0.8333 - val_loss: 2.5930
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 2.6156 - val_accuracy: 0.8333 - val_loss: 2.5607
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5333 - loss: 2.5906 - val_accuracy: 0.8333 - val_loss: 2.5215
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5333 - loss: 2.5605 - val_accuracy: 0.8333 - val_loss: 2.4735
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5333 - loss: 2.5238 - val_accuracy: 0.8333 - val_loss: 2.4143
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 2.4787 - val_accuracy: 0.8333 - val_loss: 2.3414
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.5333 - loss: 2.4230 - val_accuracy: 0.8333 - val_loss: 2.2511
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5333 - loss: 2.3541 - val_accuracy: 0.8333 - val_loss: 2.1398
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5333 - loss: 2.2690 - val_accuracy: 0.8333 - val_loss: 2.0030
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5333 - loss: 2.1643 - val_accuracy: 0.8333 - val_loss: 1.8375
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5333 - loss: 2.0382 - val_accuracy: 0.8333 - val_loss: 1.6436
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5333 - loss: 1.8925 - val_accuracy: 0.8333 - val_loss: 1.4317
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5333 - loss: 1.7383 - val_accuracy: 0.8333 - val_loss: 1.2310
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5333 - loss: 1.6021 - val_accuracy: 0.8333 - val_loss: 1.0872
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 1.5271 - val_accuracy: 0.8333 - val_loss: 1.0344
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 1.5470 - val_accuracy: 0.8333 - val_loss: 1.0517
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5333 - loss: 1.6113 - val_accuracy: 0.8333 - val_loss: 1.0804
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.5333 - loss: 1.6372 - val_accuracy: 0.8333 - val_loss: 1.0942
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5333 - loss: 1.6077 - val_accuracy: 0.8333 - val_loss: 1.0940
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.5333 - loss: 1.5445 - val_accuracy: 0.8333 - val_loss: 1.0884
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5333 - loss: 1.4746 - val_accuracy: 0.8333 - val_loss: 1.0861
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5333 - loss: 1.4177 - val_accuracy: 0.8333 - val_loss: 1.0918
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 1.3823 - val_accuracy: 0.8333 - val_loss: 1.1058
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 1.3668 - val_accuracy: 0.8333 - val_loss: 1.1248
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5333 - loss: 1.3638 - val_accuracy: 0.8333 - val_loss: 1.1442
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5333 - loss: 1.3650 - val_accuracy: 0.8333 - val_loss: 1.1604
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.5333 - loss: 1.3640 - val_accuracy: 0.8333 - val_loss: 1.1714
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5333 - loss: 1.3574 - val_accuracy: 0.8333 - val_loss: 1.1776
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5333 - loss: 1.3440 - val_accuracy: 0.8333 - val_loss: 1.1806
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5333 - loss: 1.3245 - val_accuracy: 0.8333 - val_loss: 1.1830
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 1.3006 - val_accuracy: 0.8333 - val_loss: 1.1878
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5333 - loss: 1.2748 - val_accuracy: 0.8333 - val_loss: 1.1977
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5333 - loss: 1.2499 - val_accuracy: 0.8333 - val_loss: 1.2144
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 1.2283 - val_accuracy: 0.8333 - val_loss: 1.2381
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 1.2116 - val_accuracy: 0.8333 - val_loss: 1.2677
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.5333 - loss: 1.1995 - val_accuracy: 0.8333 - val_loss: 1.3006
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5333 - loss: 1.1904 - val_accuracy: 0.8333 - val_loss: 1.3337
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5333 - loss: 1.1819 - val_accuracy: 0.8333 - val_loss: 1.3640
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.5333 - loss: 1.1714 - val_accuracy: 0.8333 - val_loss: 1.3897
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5333 - loss: 1.1576 - val_accuracy: 0.8333 - val_loss: 1.4104
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.5333 - loss: 1.1405 - val_accuracy: 0.8333 - val_loss: 1.4267
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 1.1214 - val_accuracy: 0.8333 - val_loss: 1.4405
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.5333 - loss: 1.1022 - val_accuracy: 0.8333 - val_loss: 1.4535
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 1.0843 - val_accuracy: 0.8333 - val_loss: 1.4677
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5333 - loss: 1.0684 - val_accuracy: 0.8333 - val_loss: 1.4844
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5333 - loss: 1.0542 - val_accuracy: 0.8333 - val_loss: 1.5045
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.5333 - loss: 1.0406 - val_accuracy: 0.8333 - val_loss: 1.5287
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.5333 - loss: 1.0264 - val_accuracy: 0.8333 - val_loss: 1.5572
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5333 - loss: 1.0105 - val_accuracy: 0.8333 - val_loss: 1.5904
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.5333 - loss: 0.9925 - val_accuracy: 0.8333 - val_loss: 1.6285
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.5333 - loss: 0.9727 - val_accuracy: 0.8333 - val_loss: 1.6716
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.5333 - loss: 0.9519 - val_accuracy: 0.8333 - val_loss: 1.7191
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5333 - loss: 0.9310 - val_accuracy: 0.8333 - val_loss: 1.7701
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5333 - loss: 0.9106 - val_accuracy: 0.8333 - val_loss: 1.8229
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 0.8907 - val_accuracy: 0.8333 - val_loss: 1.8757
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5333 - loss: 0.8706 - val_accuracy: 0.8333 - val_loss: 1.9268
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5333 - loss: 0.8492 - val_accuracy: 0.8333 - val_loss: 1.9754
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.5333 - loss: 0.8261 - val_accuracy: 0.8333 - val_loss: 2.0217
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6000 - loss: 0.8013 - val_accuracy: 0.8333 - val_loss: 2.0670
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6000 - loss: 0.7755 - val_accuracy: 0.8333 - val_loss: 2.1132
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7333 - loss: 0.7493 - val_accuracy: 0.8333 - val_loss: 2.1622
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7333 - loss: 0.7231 - val_accuracy: 0.8333 - val_loss: 2.2155
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8667 - loss: 0.6968 - val_accuracy: 0.8333 - val_loss: 2.2740
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9333 - loss: 0.6696 - val_accuracy: 0.8333 - val_loss: 2.3377
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9333 - loss: 0.6411 - val_accuracy: 0.6667 - val_loss: 2.4061
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9333 - loss: 0.6115 - val_accuracy: 0.6667 - val_loss: 2.4778
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9333 - loss: 0.5813 - val_accuracy: 0.6667 - val_loss: 2.5511
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9333 - loss: 0.5513 - val_accuracy: 0.6667 - val_loss: 2.6234
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9333 - loss: 0.5217 - val_accuracy: 0.6667 - val_loss: 2.6923
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9333 - loss: 0.4922 - val_accuracy: 0.6667 - val_loss: 2.7560
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.4626 - val_accuracy: 0.6667 - val_loss: 2.8139
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.4328 - val_accuracy: 0.6667 - val_loss: 2.8670
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.4035 - val_accuracy: 0.6667 - val_loss: 2.9171
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.3751 - val_accuracy: 0.6667 - val_loss: 2.9659
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.3474 - val_accuracy: 0.6667 - val_loss: 3.0146
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.3198 - val_accuracy: 0.6667 - val_loss: 3.0631
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 1.0000 - loss: 0.2921 - val_accuracy: 0.6667 - val_loss: 3.1098
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.2652 - val_accuracy: 0.6667 - val_loss: 3.1523
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.2396 - val_accuracy: 0.6667 - val_loss: 3.1888
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.2151 - val_accuracy: 0.6667 - val_loss: 3.2189
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.1917 - val_accuracy: 0.6667 - val_loss: 3.2439
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.1697 - val_accuracy: 0.6667 - val_loss: 3.2662
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.1498 - val_accuracy: 0.6667 - val_loss: 3.2882
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.1320 - val_accuracy: 0.6667 - val_loss: 3.3111
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 1.0000 - loss: 0.1158 - val_accuracy: 0.6667 - val_loss: 3.3343
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - loss: 0.1016 - val_accuracy: 0.6667 - val_loss: 3.3569
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 1.0000 - loss: 0.0896 - val_accuracy: 0.6667 - val_loss: 3.3776
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0795 - val_accuracy: 0.6667 - val_loss: 3.3962
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 1.0000 - loss: 0.0709 - val_accuracy: 0.6667 - val_loss: 3.4132
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0635 - val_accuracy: 0.6667 - val_loss: 3.4293
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0573 - val_accuracy: 0.6667 - val_loss: 3.4456
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0521 - val_accuracy: 0.6667 - val_loss: 3.4624
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0475 - val_accuracy: 0.6667 - val_loss: 3.4796
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 0.0434 - val_accuracy: 0.6667 - val_loss: 3.4962
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 1.0000 - loss: 0.0399 - val_accuracy: 0.6667 - val_loss: 3.5116
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0369 - val_accuracy: 0.6667 - val_loss: 3.5251
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0343 - val_accuracy: 0.6667 - val_loss: 3.5367
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0319 - val_accuracy: 0.6667 - val_loss: 3.5471
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0298 - val_accuracy: 0.6667 - val_loss: 3.5567
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0279 - val_accuracy: 0.6667 - val_loss: 3.5662
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 1.0000 - loss: 0.0262 - val_accuracy: 0.6667 - val_loss: 3.5760
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0247 - val_accuracy: 0.6667 - val_loss: 3.5863
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0232 - val_accuracy: 0.6667 - val_loss: 3.5969
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.6667 - val_loss: 3.6073
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0206 - val_accuracy: 0.6667 - val_loss: 3.6172
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0195 - val_accuracy: 0.6667 - val_loss: 3.6264
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0185 - val_accuracy: 0.6667 - val_loss: 3.6348
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0175 - val_accuracy: 0.6667 - val_loss: 3.6424
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 0.6667 - val_loss: 3.6494
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0158 - val_accuracy: 0.6667 - val_loss: 3.6561
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.6667 - val_loss: 3.6628
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.6667 - val_loss: 3.6695
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.6667 - val_loss: 3.6765
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 0.6667 - val_loss: 3.6836
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.6667 - val_loss: 3.6907
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 0.6667 - val_loss: 3.6976
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 0.6667 - val_loss: 3.7043
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.6667 - val_loss: 3.7107
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.6667 - val_loss: 3.7165
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.6667 - val_loss: 3.7220
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.6667 - val_loss: 3.7270
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.6667 - val_loss: 3.7317
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0091 - val_accuracy: 0.6667 - val_loss: 3.7362
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.6667 - val_loss: 3.7406
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.6667 - val_loss: 3.7448
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.6667 - val_loss: 3.7490
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.6667 - val_loss: 3.7532
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.6667 - val_loss: 3.7572
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.6667 - val_loss: 3.7612
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.6667 - val_loss: 3.7651
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0071 - val_accuracy: 0.6667 - val_loss: 3.7689
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0069 - val_accuracy: 0.6667 - val_loss: 3.7726
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.6667 - val_loss: 3.7761
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.6667 - val_loss: 3.7795
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.6667 - val_loss: 3.7828
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.6667 - val_loss: 3.7861
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.6667 - val_loss: 3.7893
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0060 - val_accuracy: 0.6667 - val_loss: 3.7925
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.6667 - val_loss: 3.7957
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0057 - val_accuracy: 0.6667 - val_loss: 3.7989
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.6667 - val_loss: 3.8020
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.6667 - val_loss: 3.8050
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.6667 - val_loss: 3.8079
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.6667 - val_loss: 3.8108
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.6667 - val_loss: 3.8136
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.6667 - val_loss: 3.8162
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.6667 - val_loss: 3.8188
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.6667 - val_loss: 3.8212
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.6667 - val_loss: 3.8236
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.6667 - val_loss: 3.8259
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.6667 - val_loss: 3.8282
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.6667 - val_loss: 3.8305
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.6667 - val_loss: 3.8328
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.6667 - val_loss: 3.8350
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.6667 - val_loss: 3.8373
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.6667 - val_loss: 3.8395
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.6667 - val_loss: 3.8417
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.6667 - val_loss: 3.8439
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.6667 - val_loss: 3.8461
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.6667 - val_loss: 3.8482
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.6667 - val_loss: 3.8502
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.6667 - val_loss: 3.8523
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.6667 - val_loss: 3.8543
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.6667 - val_loss: 3.8562
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.6667 - val_loss: 3.8582
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.6667 - val_loss: 3.8601
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.6667 - val_loss: 3.8620
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.6667 - val_loss: 3.8638
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.6667 - val_loss: 3.8657
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.6667 - val_loss: 3.8676
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.6667 - val_loss: 3.8694
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.6667 - val_loss: 3.8713
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.6667 - val_loss: 3.8731
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.6667 - val_loss: 3.8749
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.6667 - val_loss: 3.8766
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.6667 - val_loss: 3.8783
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.6667 - val_loss: 3.8800
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.6667 - val_loss: 3.8817
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.6667 - val_loss: 3.8833
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.6667 - val_loss: 3.8849
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.6667 - val_loss: 3.8865
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.6667 - val_loss: 3.8880
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.6667 - val_loss: 3.8895
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.6667 - val_loss: 3.8910
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.6667 - val_loss: 3.8925
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.6667 - val_loss: 3.8939
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.6667 - val_loss: 3.8953
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.6667 - val_loss: 3.8967
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.6667 - val_loss: 3.8981
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.6667 - val_loss: 3.8995
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.6667 - val_loss: 3.9008
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.6667 - val_loss: 3.9021
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.6667 - val_loss: 3.9035
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.6667 - val_loss: 3.9048
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.6667 - val_loss: 3.9061
